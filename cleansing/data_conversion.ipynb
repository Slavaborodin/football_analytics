# %% [markdown]
# # Cleaning the Premier League datasets from 2017-2020

# %% [markdown]
# To start with we will focus on the Premier League seasons only and in later notebook we will focus on other leagues and players. In this notebook we will focus on extracting the data from raw JSON format into a more readable format. All source files are stored in the 'src_files/Football_Players' directory which were retrieved from the public dataset available on Kaggle : https://www.kaggle.com/datasets/diegobartoli/top5legauesplayers-statsandphys

# %%
import pandas as pd
import os
import matplotlib.pylab as plt
import seaborn as sns
import json 
import numpy


# %matplotlib inline

# %% [markdown]
# # Import Data from raw JSON

# %%
data_pl_2017 = pd.read_json("../src_files/Football_Players/2017PremierLeague.json",lines=True)
data_pl_2018 = pd.read_json("../src_files/Football_Players/2018PremierLeague.json",lines=True)
data_pl_2019 = pd.read_json("../src_files/Football_Players/2019PremierLeague.json",lines=True)
data_pl_2020 = pd.read_json("../src_files/Football_Players/2020PremierLeague.json",lines=True)

# %%
data_pl_2017.head(5)
# Out:
#                                     _id  age  \
# 0  {'$oid': '61eda24e19e7e448017988d0'}   33
# 1  {'$oid': '61eda24e19e7e448017988d1'}   25
# 2  {'$oid': '61eda24e19e7e448017988d2'}   31
# 3  {'$oid': '61eda24e19e7e448017988d3'}   34
# 4  {'$oid': '61eda24e19e7e448017988d4'}   36
#
#                                      defensive_stats  \
# 0  {'Tkl': 36.0, 'TklW': 23.0, 'Past': 8.0, 'Pres...
# 1  {'Tkl': 18.0, 'TklW': 16.0, 'Past': 14.0, 'Pre...
# 2  {'Tkl': 18.0, 'TklW': 12.0, 'Past': 18.0, 'Pre...
# 3  {'Tkl': 19.0, 'TklW': 13.0, 'Past': 18.0, 'Pre...
# 4  {'Tkl': 47.0, 'TklW': 27.0, 'Past': 28.0, 'Pre...
#
#                                        general_stats  height           name  \
# 0  {'games': 32.0, 'time': 2817.0, 'red_cards': 0...     186     Wes Morgan
# 1  {'games': 20.0, 'time': 1179.0, 'red_cards': 0...     172  Jack Wilshere
# 2  {'games': 25.0, 'time': 1842.0, 'red_cards': 0...     178  Andrew Surman
# 3  {'games': 35.0, 'time': 2204.0, 'red_cards': 0...     183   Glenn Murray
# 4  {'games': 25.0, 'time': 1935.0, 'red_cards': 0...     183   Gareth Barry
#
#   nationality                                    offensive_stats  \
# 0     Jamaica  {'goals': 0.0, 'xG': 1.9300000000000002, 'assi...
# 1     England  {'goals': 1.0, 'xG': 1.16, 'assists': 3.0, 'xA...
# 2     England  {'goals': 2.0, 'xG': 0.99, 'assists': 5.0, 'xA...
# 3     England  {'goals': 12.0, 'xG': 12.38, 'assists': 0.0, '...
# 4     England  {'goals': 1.0, 'xG': 1.3599999999999999, 'assi...
#
#                                        passing_stats position  \
# 0  {'Cmp': 739.0, 'Cmp%': 84.1, '1/3': 35.0, 'PPA...       DF
# 1  {'Cmp': 703.0, 'Cmp%': 86.6, '1/3': 64.0, 'PPA...       MF
# 2  {'Cmp': 997.0, 'Cmp%': 84.4, '1/3': 97.0, 'PPA...       MF
# 3  {'Cmp': 380.0, 'Cmp%': 58.0, '1/3': 18.0, 'PPA...       FW
# 4  {'Cmp': 720.0, 'Cmp%': 75.9, '1/3': 99.0, 'PPA...       MF
#
#                    team  weight
# 0             Leicester     101
# 1               Arsenal      68
# 2           Bournemouth      73
# 3              Brighton      80
# 4  West Bromwich Albion      78

# %%
data_pl_2018.head(5)
# Out:
#                                     _id  age  \
# 0  {'$oid': '61eda25019e7e44801798eb5'}   34
# 1  {'$oid': '61eda25019e7e44801798eb6'}   33
# 2  {'$oid': '61eda25019e7e44801798eb7'}   32
# 3  {'$oid': '61eda25019e7e44801798eb8'}   35
# 4  {'$oid': '61eda25019e7e44801798eb9'}   30
#
#                                      defensive_stats  \
# 0  {'Tkl': 32.0, 'TklW': 17.0, 'Past': 2.0, 'Pres...
# 1  {'Tkl': 24.0, 'TklW': 15.0, 'Past': 15.0, 'Pre...
# 2  {'Tkl': 15.0, 'TklW': 10.0, 'Past': 12.0, 'Pre...
# 3  {'Tkl': 14.0, 'TklW': 7.0, 'Past': 19.0, 'Pres...
# 4  {'Tkl': 11.0, 'TklW': 8.0, 'Past': 9.0, 'Press...
#
#                                        general_stats  height            name  \
# 0  {'games': 22.0, 'time': 1932.0, 'red_cards': 2...   186.0      Wes Morgan
# 1  {'games': 17.0, 'time': 1220.0, 'red_cards': 0...   183.0   Simon Francis
# 2  {'games': 18.0, 'time': 1440.0, 'red_cards': 0...   178.0   Andrew Surman
# 3  {'games': 38.0, 'time': 2517.0, 'red_cards': 0...   183.0    Glenn Murray
# 4  {'games': 15.0, 'time': 843.0, 'red_cards': 1....   188.0  Kevin McDonald
#
#   nationality                                    offensive_stats  \
# 0     Jamaica  {'goals': 3.0, 'xG': 1.54, 'assists': 0.0, 'xA...
# 1     England  {'goals': 0.0, 'xG': 0.12, 'assists': 2.0, 'xA...
# 2     England  {'goals': 0.0, 'xG': 0.27, 'assists': 0.0, 'xA...
# 3     England  {'goals': 13.0, 'xG': 11.54, 'assists': 1.0, '...
# 4    Scotland  {'goals': 0.0, 'xG': 0.11, 'assists': 0.0, 'xA...
#
#                                        passing_stats position         team  \
# 0  {'Cmp': 742.0, 'Cmp%': 83.5, '1/3': 30.0, 'PPA...       DF    Leicester
# 1  {'Cmp': 598.0, 'Cmp%': 74.0, '1/3': 56.0, 'PPA...       DF  Bournemouth
# 2  {'Cmp': 725.0, 'Cmp%': 87.2, '1/3': 58.0, 'PPA...       MF  Bournemouth
# 3  {'Cmp': 378.0, 'Cmp%': 60.7, '1/3': 25.0, 'PPA...       FW     Brighton
# 4  {'Cmp': 488.0, 'Cmp%': 85.8, '1/3': 42.0, 'PPA...       MF       Fulham
#
#    weight
# 0   101.0
# 1    90.0
# 2    73.0
# 3    80.0
# 4    82.0

# %%
data_pl_2019.head(5)
# Out:
#                                     _id  age  \
# 0  {'$oid': '61eda25119e7e448017994e0'}   34
# 1  {'$oid': '61eda25119e7e448017994e1'}   36
# 2  {'$oid': '61eda25119e7e448017994e2'}   32
# 3  {'$oid': '61eda25119e7e448017994e3'}   31
# 4  {'$oid': '61eda25119e7e448017994e4'}   33
#
#                                      defensive_stats  \
# 0  {'Tkl': 17.0, 'TklW': 12.0, 'Past': 14.0, 'Pre...
# 1  {'Tkl': 3.0, 'TklW': 2.0, 'Past': 6.0, 'Press'...
# 2  {'Tkl': 25.0, 'TklW': 17.0, 'Past': 12.0, 'Pre...
# 3  {'Tkl': 7.0, 'TklW': 5.0, 'Past': 5.0, 'Press'...
# 4  {'Tkl': 25.0, 'TklW': 12.0, 'Past': 27.0, 'Pre...
#
#                                        general_stats  height  \
# 0  {'games': 15.0, 'time': 956.0, 'red_cards': 1....   183.0
# 1  {'games': 23.0, 'time': 761.0, 'red_cards': 0....   183.0
# 2  {'games': 18.0, 'time': 1007.0, 'red_cards': 0...   183.0
# 3  {'games': 24.0, 'time': 1462.0, 'red_cards': 0...   173.0
# 4  {'games': 20.0, 'time': 1503.0, 'red_cards': 1...   180.0
#
#                name nationality  \
# 0     Simon Francis     England
# 1      Glenn Murray     England
# 2  Ahmed Elmohamady       Egypt
# 3     Sergio Agüero   Argentina
# 4   Adrian Mariappa     Jamaica
#
#                                      offensive_stats  \
# 0  {'goals': 0.0, 'xG': 0.15, 'assists': 0.0, 'xA...
# 1  {'goals': 1.0, 'xG': 2.61, 'assists': 1.0, 'xA...
# 2  {'goals': 1.0, 'xG': 0.2, 'assists': 1.0, 'xA'...
# 3  {'goals': 16.0, 'xG': 15.56, 'assists': 3.0, '...
# 4  {'goals': 0.0, 'xG': 0.17, 'assists': 0.0, 'xA...
#
#                                        passing_stats position  \
# 0  {'Cmp': 425.0, 'Cmp%': 78.1, '1/3': 26.0, 'PPA...       DF
# 1  {'Cmp': 116.0, 'Cmp%': 65.5, '1/3': 7.0, 'PPA'...       FW
# 2  {'Cmp': 484.0, 'Cmp%': 76.5, '1/3': 44.0, 'PPA...       DF
# 3  {'Cmp': 284.0, 'Cmp%': 77.4, '1/3': 12.0, 'PPA...       FW
# 4  {'Cmp': 426.0, 'Cmp%': 72.8, '1/3': 32.0, 'PPA...       DF
#
#               team  weight
# 0      Bournemouth    90.0
# 1         Brighton    80.0
# 2      Aston Villa    75.0
# 3  Manchester City    70.0
# 4          Watford    78.0

# %%
data_pl_2020.head(5)
# Out:
#                                     _id  age  \
# 0  {'$oid': '61eda25219e7e44801799abc'}   31
# 1  {'$oid': '61eda25219e7e44801799abd'}   27
# 2  {'$oid': '61eda25219e7e44801799abe'}   24
# 3  {'$oid': '61eda25219e7e44801799abf'}   33
# 4  {'$oid': '61eda25219e7e44801799ac0'}   28
#
#                                      defensive_stats  \
# 0  {'Tkl': 3.0, 'TklW': 3.0, 'Past': 0.0, 'Press'...
# 1  {'Tkl': 8.0, 'TklW': 5.0, 'Past': 10.0, 'Press...
# 2  {'Tkl': 41.0, 'TklW': 26.0, 'Past': 17.0, 'Pre...
# 3  {'Tkl': 0.0, 'TklW': 0.0, 'Past': 1.0, 'Press'...
# 4  {'Tkl': 37.0, 'TklW': 20.0, 'Past': 16.0, 'Pre...
#
#                                        general_stats  height  \
# 0  {'games': 19.0, 'time': 522.0, 'red_cards': 0....   183.0
# 1  {'games': 21.0, 'time': 512.0, 'red_cards': 0....   180.0
# 2  {'games': 31.0, 'time': 2732.0, 'red_cards': 1...   192.0
# 3  {'games': 37.0, 'time': 3330.0, 'red_cards': 0...   190.0
# 4  {'games': 27.0, 'time': 1424.0, 'red_cards': 0...   178.0
#
#                   name nationality  \
# 0      Hal Robson-Kanu       Wales
# 1  Alireza Jahanbakhsh        Iran
# 2     Joachim Andersen     Denmark
# 3       Vicente Guaita       Spain
# 4      Jeffrey Schlupp       Ghana
#
#                                      offensive_stats  \
# 0  {'goals': 2.0, 'xG': 1.5, 'assists': 0.0, 'xA'...
# 1  {'goals': 0.0, 'xG': 1.87, 'assists': 1.0, 'xA...
# 2  {'goals': 1.0, 'xG': 1.3599999999999999, 'assi...
# 3  {'goals': 0.0, 'xG': 0.0, 'assists': 0.0, 'xA'...
# 4  {'goals': 2.0, 'xG': 2.02, 'assists': 3.0, 'xA...
#
#                                        passing_stats position  \
# 0  {'Cmp': 64.0, 'Cmp%': 74.4, '1/3': 7.0, 'PPA':...       FW
# 1  {'Cmp': 196.0, 'Cmp%': 74.0, '1/3': 4.0, 'PPA'...       FW
# 2  {'Cmp': 1529.0, 'Cmp%': 83.4, '1/3': 121.0, 'P...       DF
# 3  {'Cmp': 598.0, 'Cmp%': 55.4, '1/3': 7.0, 'PPA'...       GK
# 4  {'Cmp': 304.0, 'Cmp%': 70.9, '1/3': 31.0, 'PPA...       MF
#
#                    team  weight
# 0  West Bromwich Albion    83.0
# 1              Brighton    76.0
# 2                Fulham    90.0
# 3        Crystal Palace    81.0
# 4        Crystal Palace    72.0

# %% [markdown]
# At the minute we will only focus on the premier league players and seasons from 2017-2020. We've imported the raw data from JSON as seen above for the first 5 rows for each season we are working with. We can see that the data is hard to read so we will need to do some data manipulation to convert the JSON into readable format
